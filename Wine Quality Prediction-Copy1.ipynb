# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings(action = 'ignore')
import numpy as np

# %%
wine = pd.read_csv("Downloads/archive/winequality-red.csv")

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine = wine.groupby('quality').mean()
wine.reset_index(inplace=True)

# %%
names = [0, 1, 2, 3, 4, 5]

plt.bar(wine['quality'], wine['chlorides'])
plt.show()

# %%
wine.plot(kind = 'box', subplots = True, layout =(4, 4), sharex = False)
# Out:
# quality                    Axes(0.125,0.712609;0.168478x0.167391)
# fixed acidity           Axes(0.327174,0.712609;0.168478x0.167391)
# volatile acidity        Axes(0.529348,0.712609;0.168478x0.167391)
# citric acid             Axes(0.731522,0.712609;0.168478x0.167391)
# residual sugar             Axes(0.125,0.511739;0.168478x0.167391)
# chlorides               Axes(0.327174,0.511739;0.168478x0.167391)
# free sulfur dioxide     Axes(0.529348,0.511739;0.168478x0.167391)
# total sulfur dioxide    Axes(0.731522,0.511739;0.168478x0.167391)
# density                     Axes(0.125,0.31087;0.168478x0.167391)
# pH                       Axes(0.327174,0.31087;0.168478x0.167391)
# sulphates                Axes(0.529348,0.31087;0.168478x0.167391)
# alcohol                  Axes(0.731522,0.31087;0.168478x0.167391)
# dtype: object

# %%
wine['fixed acidity'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
wine.hist(figsize=(10,10), bins=10)
plt.show()

# %%
wine.sample(5)
# Out:
#    quality  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 2        5       8.167254          0.577041     0.243686        2.528855
# 3        6       8.347179          0.497484     0.273824        2.477194
# 1        4       7.779245          0.693962     0.174151        2.694340
# 4        7       8.872362          0.403920     0.375176        2.720603
# 5        8       8.566667          0.423333     0.391111        2.577778
#
#    chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  \
# 2   0.092736            16.983847             56.513950  0.997104  3.304949
# 3   0.084956            15.711599             40.869906  0.996615  3.318072
# 1   0.090679            12.264151             36.245283  0.996542  3.381509
# 4   0.076588            14.045226             35.020101  0.996104  3.290754
# 5   0.068444            13.277778             33.444444  0.995212  3.267222
#
#    sulphates    alcohol
# 2   0.620969   9.899706
# ...

# %%
wine['goodquality'] = [1 if x >= 7 else 0 for x in wine['quality']]

# %%
wine.sample(5)
#wine['quality'].unique()
# Out:
#    quality  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 2        5       8.167254          0.577041     0.243686        2.528855
# 1        4       7.779245          0.693962     0.174151        2.694340
# 4        7       8.872362          0.403920     0.375176        2.720603
# 0        3       8.360000          0.884500     0.171000        2.635000
# 3        6       8.347179          0.497484     0.273824        2.477194
#
#    chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  \
# 2   0.092736            16.983847             56.513950  0.997104  3.304949
# 1   0.090679            12.264151             36.245283  0.996542  3.381509
# 4   0.076588            14.045226             35.020101  0.996104  3.290754
# 0   0.122500            11.000000             24.900000  0.997464  3.398000
# 3   0.084956            15.711599             40.869906  0.996615  3.318072
#
#    sulphates    alcohol  goodquality
# ...

# %%
X = wine.drop(['quality', 'goodquality'], axis=1)
y = wine['goodquality']

# %%
wine['goodquality'].value_counts()
# Out:
# goodquality
# 0    4
# 1    2
# Name: count, dtype: int64

# %%
X
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       8.360000          0.884500     0.171000        2.635000   0.122500
# 1       7.779245          0.693962     0.174151        2.694340   0.090679
# 2       8.167254          0.577041     0.243686        2.528855   0.092736
# 3       8.347179          0.497484     0.273824        2.477194   0.084956
# 4       8.872362          0.403920     0.375176        2.720603   0.076588
# 5       8.566667          0.423333     0.391111        2.577778   0.068444
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            11.000000             24.900000  0.997464  3.398000   0.570000
# 1            12.264151             36.245283  0.996542  3.381509   0.596415
# 2            16.983847             56.513950  0.997104  3.304949   0.620969
# 3            15.711599             40.869906  0.996615  3.318072   0.675329
# ...

# %%
print(y)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# 5    1
# Name: goodquality, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
classifier = ExtraTreesClassifier()
classifier.fit(X, y)
score = classifier.feature_importances_
print(score)
# Out:
# [0.09675 0.1035  0.18275 0.01425 0.0705  0.03475 0.025   0.0905  0.06375
#  0.14575 0.1725 ]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %%
model_res = pd.DataFrame(columns=['Model', 'Score'])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score, confusion_matrix
model_res.loc[len(model_res)] = ['LogisticRegression', accuracy_score(y_test, y_pred)]
model_res
# Out:
#                 Model  Score
# 0  LogisticRegression    1.0

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['KNeighbors', accuracy_score(y_test, y_pred)]
model_res
# Out:
#                 Model  Score
# 0  LogisticRegression    1.0
# 1          KNeighbors    0.5

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['SVC', accuracy_score(y_test, y_pred)]
model_res
# Out:
#                 Model  Score
# 0  LogisticRegression    1.0
# 1          KNeighbors    0.5
# 2                 SVC    0.5

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', random_state=7)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['Decision Tree Classifier', accuracy_score(y_test, y_pred)]
model_res
# Out:
#                       Model  Score
# 0        LogisticRegression    1.0
# 1                KNeighbors    0.5
# 2                       SVC    0.5
# 3  Decision Tree Classifier    1.0

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train, y_train)
y_pred = model3.predict(X_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['GaussianNB', accuracy_score(y_test, y_pred)]
model_res
# Out:
#                       Model  Score
# 0        LogisticRegression    1.0
# 1                KNeighbors    0.5
# 2                       SVC    0.5
# 3  Decision Tree Classifier    1.0
# 4                GaussianNB    0.5

# %%
from sklearn.ensemble import RandomForestClassifier
model4 = RandomForestClassifier()
model4.fit(X_train, y_train)
y_pred = model4.predict(X_test)
print(y_pred)
#from sklearn.metrics import accuracy_score
#model_res.loc[len(model_res)] = ['RandomForestClassifier', accuracy_score(y_test, y_pred)]
#model_res
# Out:
# [0 1]

# %%
import xgboost as xgb
model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, y_train)
y_pred = model5.predict(X_test)
print(y_pred)
#from sklearn.metrics import accuracy_score
#model_res.loc[len(model_res)] = ['XGB', accuracy_score(y_test, y_pred)]
#model_res
# Out:
# [0 0]
